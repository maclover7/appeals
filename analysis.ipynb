# %% [markdown]
# # Analyze property assessment appeals for 2022S and 2023

# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
db = create_engine('postgresql://jon@localhost:5432/propertydb')

# %% [markdown]
# ### Owner appeals of county's top 50 parcels

# %%
top50parcels = pd.read_sql_query("""SELECT parcelid
FROM assessments
WHERE assessments.taxcode = 'T'
ORDER BY fairmarkettotal::int DESC
LIMIT 50;""", db)

# %%
pd.read_sql_query("""SELECT COUNT(DISTINCT parcelid)
FROM appeals
WHERE filer = 'PROPERTY OWNER'
AND appealperiod IN ('2022S', '2023')
AND parcelid IN %(parcels)s;""", db, params={'parcels': tuple(top50parcels.parcelid)})
# Out:
#    count
# 0     21

# %% [markdown]
# ### Owner appeals of PGH 1st/2nd ward office parcels

# %%
# 405: RETL/OFF OVER
# 431: OFFICE/APARTMENTS OVER
# 433: OFFICE/STORAGE OVER
# 447: OFFICE - 1-2 STORIES
# 448: OFFICE-WALKUP -3 + STORIES
# 449: OFFICE-ELEVATOR -3 + STORIES
# 450: CONDOMINIUM OFFICE BUILDING

pghdowntownofficeparcels = pd.read_sql_query("""SELECT DISTINCT parcelid
FROM assessments
WHERE taxcode = 'T'
AND municode IN ('101', '102')
AND usecode IN ('405', '431', '433', '447', '448', '449', '450');""", db)

# %%
pghdowntownofficeparcelappeals = pd.read_sql_query("""SELECT DISTINCT parcelid
FROM appeals
WHERE filer = 'PROPERTY OWNER'
AND appealperiod IN ('2022S', '2023')
AND parcelid IN %(parcels)s;""", db, params={'parcels': tuple(pghdowntownofficeparcels.parcelid)})

[
    len(pghdowntownofficeparcelappeals),
    len(pghdowntownofficeparcelappeals) / len(pghdowntownofficeparcels)
]
# Out:
# [45, 0.1595744680851064]

# %% [markdown]
# ### Owner appeals of shopping centers

# %%
# 426: COMMUNITY SHOPPING CENTER
# 427: REGIONAL SHOPPING CENTER

pd.read_sql_query("""SELECT DISTINCT appeals.parcelid, appeals.address, appeals.muni, appeals.owner, assessments.fairmarkettotal::int AS fairmarkettotalint
FROM appeals
JOIN assessments
ON appeals.parcelid = assessments.parcelid
WHERE appeals.filer = 'PROPERTY OWNER'
AND appeals.appealperiod IN ('2022S', '2023')
AND assessments.taxcode = 'T'
AND assessments.usecode IN ('426', '427')
ORDER BY fairmarkettotalint DESC;""", db)
# Out:
#             parcelid                                            address
# 0   0336D00150000000         100 ROBINSON CENTRE DR PITTSBURGH PA 15205  \
# 1   0743M00275000000         4100 WILLIAM PENN HWY MONROEVILLE PA 15146
# 2   0335A00025000000      1020-2001 PARK MANOR BLVD PITTSBURGH PA 15205
# 3   0352G00078000000               4801 MCKNIGHT RD PITTSBURGH PA 15237
# 4   0319M00300000000                4000 OXFORD DR BETHEL PARK PA 15102
# 5   0189S00183000000           600 TOWNE SQUARE WAY PITTSBURGH PA 15227
# 6   0612S00150000000   3000-3380 MCINTYRE SQUARE DR PITTSBURGH PA 15237
# 7   0638R00064000000    3739-3769 WILLIAM PENN HWY MONROEVILLE PA 15146
# 8   0840K00100000000     167-592 PITTSBURGH MILLS CIR TARENTUM PA 15084
# 9   0265E00100000000  800-1230 SETTLERS RIDGE CENTER DR PITTSBURGH P...
# 10  0542F00120000000          3470 WILLIAM PENN HWY PITTSBURGH PA 15235
# 11  0542E00175000000     3424-3436 WILLIAM PENN HWY PITTSBURGH PA 15235
# 12  0252S00300000000             1500 WASHINGTON RD PITTSBURGH PA 15228
# 13  0252S00125000000             1500 WASHINGTON RD PITTSBURGH PA 15228
# 14  0265E00125000000  210-295 SETTLERS RIDGE CENTER DR PITTSBURGH PA...
# 15  0265E00001000000  1310-1350 SETTLERS RIDGE CENTER DR PITTSBURGH ...
# 16  0089S00175000000             210-270 W BRIDGE ST HOMESTEAD PA 15120
# 17  1212J00107000000                 4960 ROUTE 8 ALLISON PARK PA 15101
# 18  0100G00201000000              2101 GREENTREE RD PITTSBURGH PA 15220
# 19  1212J00127000000                 4960 ROUTE 8 ALLISON PARK PA 15101
# 20  0336K00030000000        3000 ROBINSON CENTRE DR PITTSBURGH PA 15205
# 21  0857D00259000000             2644 MOSSIDE BLVD MONROEVILLE PA 15146
# 22  0554E00210000000                4313 WALNUT ST MC KEESPORT PA 15132
# 23  0431F00028000000               7215 MCKNIGHT RD PITTSBURGH PA 15237
# 24  0861E00229000000       4500-4548 BROADWAY BLVD MONROEVILLE PA 15146
# 25  0336P00030000000        2000 ROBINSON CENTRE DR PITTSBURGH PA 15205
# 26  0516D00070000000            1124-1130 PERRY HWY PITTSBURGH PA 15237
# 27  1244L00372000000    5020-5072 WILLIAM PENN HWY MONROEVILLE PA 15146
# 28  0412G00005000000             200-250 MCHOLME DR PITTSBURGH PA 15275
# 29  0977F00198000000     4680 OLD WILLIAM PENN HWY MONROEVILLE PA 15146
# 30  0089M00075000000             217-245 W BRIDGE ST HOMESTEAD PA 15120
# 31  0336K00049000000   6503-6535 ROBINSON CENTRE DR PITTSBURGH PA 15205
# 32  0336P00040000000         100 ROBINSON CENTRE DR PITTSBURGH PA 15205
# 33  0196R00016000000          1155 WASHINGTON PIKE BRIDGEVILLE PA 15017
# 34  1832G00146000000        500 GRANDVIEW CROSSING DR GIBSONIA PA 15044
# 35  0639E00025000000            501 MALL CIRCLE DR MONROEVILLE PA 15146
# 36  0412G00006000000             302-324 MCHOLME DR PITTSBURGH PA 15275
# 37  0568A00280000000                145 MCMURRAY RD PITTSBURGH PA 15241
# 38  0089M00085000000                 299 W BRIDGE ST HOMESTEAD PA 15120
# 39  0612S00140000000       20-22 MCINTYRE SQUARE DR PITTSBURGH PA 15237
# 40  0336R00030000000        5000 ROBINSON CENTRE DR PITTSBURGH PA 15205
#
#                muni                                       owner
# 0          ROBINSON           ROBINSON MALL REALTY HOLDINGS LLC  \
# 1       MONROEVILLE              PZ MIRACLE LIMITED PARTNERSHIP
# 2          ROBINSON                             PARK ASSOCIATES
# 3              ROSS                 GUMBERG STANLEY R & TRUSTEE
# 4       BETHEL PARK             4000 OXFORD DRIVE ASSOCIATES LP
# 5         BRENTWOOD                         FRONTIER ASSOCIATES
# 6              ROSS                 MC INTYRE SQUARE ASSOCIATES
# 7       MONROEVILLE                         RCG-MONROEVILLE LLC
# 8            FRAZER                    PITT GALLERIA REALTY LLC
# 9          ROBINSON                           SETTLERS RIDGE LP
# 10          WILKINS                      FULTONBSII MVPA II LLC
# 11          WILKINS                            PCE PARTNERS LLC
# 12       MT.LEBANON                     CONTINENTAL/GALLERIA LP
# 13       MT.LEBANON                     CONTINENTAL/GALLERIA LP
# 14         ROBINSON                           SETTLERS RIDGE LP
# 15         ROBINSON                SETTLERS RIDGE MANAGEMENT LP
# 16   WEST HOMESTEAD    M & J - BIG WATERFRONT TOWN CENTER I LLC
# 17          HAMPTON             SHOPPERS PLAZA LAND COMPANY LLC
# 18            SCOTT                     PITTSBURGH PA RETAIL LP
# 19          HAMPTON             SHOPPERS PLAZA LAND COMPANY LLC
# 20         ROBINSON               MAY DEPARTMENT STORES COMPANY
# 21      MONROEVILLE              MOSSIDE VILLAGE ASSOCIATES LLC
# 22       VERSAILLES                    OLYMPIA LAND COMPANY LLC
# 23             ROSS                 PGH SELF SERVICE ASSOCIATES
# 24      MONROEVILLE              SKYWOOD PROPERTIES COMPANY LLC
# 25         ROBINSON                             CTL PROPCO1 LLC
# 26             ROSS                        GALILEE LAND COMPANY
# 27      MONROEVILLE    MONROEVILLE ZAMAGIAS LIMITED PARTNERSHIP
# 28    NORTH FAYETTE     MONTOUR CHURCH ROAD LIMITED PARTNERSHIP
# 29      MONROEVILLE  MONROEVILLE PLAZA 1989 LIMITED PARTNERSHIP
# 30   WEST HOMESTEAD    M & J - BIG WATERFRONT TOWN CENTER I LLC
# 31         ROBINSON                         ROBINSON STATION LP
# 32         ROBINSON           ROBINSON MALL REALTY HOLDINGS LLC
# 33          COLLIER                PZ PLAZA LIMITED PARTNERSHIP
# 34         RICHLAND               GRANDVIEW CROSSING REALTY LLC
# 35      MONROEVILLE      MONROEVILLE ANCHOR LIMITED PARTNERSHIP
# 36    NORTH FAYETTE     MONTOUR CHURCH ROAD LIMITED PARTNERSHIP
# 37  UPPER ST. CLAIR                            CAMELOT 1938 LLC
# 38   WEST HOMESTEAD    M & J - BIG WATERFRONT TOWN CENTER I LLC
# 39             ROSS                  MCINTYRE SQUARE ASSOCIATES
# 40         ROBINSON           ROBINSON MALL REALTY HOLDINGS LLC
#
#     fairmarkettotalint
# 0             88300000
# 1             60418700
# 2             56696800
# 3             53540100
# 4             31711100
# 5             21984900
# 6             18184800
# 7             14800000
# 8             14050000
# 9             13760076
# 10            12953700
# 11            11766300
# 12            11681300
# 13            11681250
# 14            10681865
# 15             8786767
# 16             8015550
# 17             7935000
# 18             7718000
# 19             6598400
# 20             6500000
# 21             6095000
# 22             5883700
# 23             5789100
# 24             5700000
# 25             5560360
# 26             5250000
# 27             5000000
# 28             4778500
# 29             4370000
# 30             4065900
# 31             3812300
# 32             3400000
# 33             3300000
# 34             3000000
# 35             2800000
# 36             2718700
# 37             2185000
# 38             1858650
# 39             1820600
# 40              600000

# %% [markdown]
# ### Owner appeals by property type

# %%
pd.read_sql_query("""SELECT type, COUNT(DISTINCT parcelid)
FROM appeals
WHERE filer = 'PROPERTY OWNER'
AND appealperiod IN ('2022S', '2023')
GROUP BY "type";""", db)
# Out:
#              type  count
# 0    C-COMMERCIAL    998
# 1    C-Commercial      1
# 2  F-AGRICULTURAL      6
# 3    G-GOVERNMENT     10
# 4    I-INDUSTRIAL     83
# 5         O-OTHER      2
# 6   R-RESIDENTIAL   5384
# 7     U-UTILITIES      3

# %% [markdown]
# # Transform data for map visualizations

# %% [markdown]
# ### Get name, code and base-year market value of municipalities

# %%
munis = pd.read_sql_query("""SELECT DISTINCT municode::int, TRIM(UPPER(munidesc)) AS munidesc, SUM(fairmarkettotal::int) AS market
FROM assessments
WHERE assessments.taxcode = 'T'
GROUP BY municode, munidesc;""", db)

# %% [markdown]
# ### Get # of appeals, assessed value of appeals for municipalities

# %%
ownerappealsbymuni = pd.read_sql_query("""SELECT DISTINCT appeals.parcelid, assessments.municode::int, assessments.fairmarkettotal::int AS appeal
FROM appeals
JOIN assessments
ON appeals.parcelid = assessments.parcelid
WHERE appeals.filer = 'PROPERTY OWNER'
AND appeals.appealperiod IN ('2022S', '2023');""", db)

ownerappealsbymuni = ownerappealsbymuni.groupby('municode').agg(
    parcelcount=('parcelid', 'size'),
    appeal=('appeal', 'sum')
).reset_index()

# Fill NA values where applicable
ownerappealsbymuni['parcelcount'] = ownerappealsbymuni.parcelcount.fillna(0)
ownerappealsbymuni['appeal'] = ownerappealsbymuni.appeal.fillna(0)

# %%
ownerappealsbymuni = pd.merge(munis, ownerappealsbymuni, on='municode', how='outer')

# %% [markdown]
# ### Sum Clairton/Duquesne/McKeesport at city level

# %%
for city in [
    {'code': 200, 'name': 'CLAIRTON'},
    {'code': 300, 'name': 'DUQUESNE'},
    {'code': 400, 'name': 'MCKEESPORT'}
]:
    citywards = ownerappealsbymuni[
        (ownerappealsbymuni.municode > city['code']) &
        (ownerappealsbymuni.municode < city['code'] + 100)
    ]

    ownerappealsbymuni.loc[len(ownerappealsbymuni.index)] = [
        city['code'],
        city['name'],
        citywards['market'].sum(),
        citywards['parcelcount'].sum(),
        citywards['appeal'].sum()
    ]

    ownerappealsbymuni = ownerappealsbymuni.drop(citywards.index).reset_index(drop=True)

# %% [markdown]
# ### Calculate percent appealed of assessed value for municipalities

# %%
ownerappealsbymuni['appealpct'] = 100 * (ownerappealsbymuni.appeal / ownerappealsbymuni.market)
ownerappealsbymuni['appealpct'] = ownerappealsbymuni.appealpct.round(1)

# %% [markdown]
# ### Print to CSV for datawrapper

# %%
ownerappealsbymuni[['municode', 'market', 'appeal', 'parcelcount', 'appealpct']].to_csv('output/map.csv', index=False)
